# %%
json_path="sample_train.json"
# load the json 
import json
with open(json_path) as f:
        datas = json.load(f)
# plot the data

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
len(datas)
# Out:
# 3

# %%
X=datas[0]["x"]

for data in datas: 
    print(data.keys())
    plt.plot(X,data["y"],label=data["name"])

plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Test accuracy for the regularized cross entropy loss")
plt.legend()
# Out:
# dict_keys(['line', 'name', 'x', 'y', 'type', 'task'])
# dict_keys(['line', 'name', 'x', 'y', 'type', 'task'])
# dict_keys(['line', 'name', 'x', 'y', 'type', 'task'])
